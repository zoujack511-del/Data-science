# %% [markdown]
#  Install the coverage module by running the following command in your terminal:
#  'pip install pytest-cov   '
#  Use the coverage module to track statement and branch coverage in your tests. This will help you evaluate how well your test cases cover the implemented functionality.
